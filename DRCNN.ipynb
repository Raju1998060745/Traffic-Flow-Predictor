# %%
import numpy as np
import pandas as pd
import folium
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Activation, Dropout, Dense, SimpleRNN
from tensorflow.keras.optimizers import Adam

# %%
# Loading the dataset
data = pd.read_csv("metr-la.csv", parse_dates=['timestamp'], index_col='timestamp')

# Selecting the sensor data
sensor_data = data.iloc[:, 1:]

# Normalizing the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(sensor_data)

# Function to create input-output pairs
def create_sequences(data, lookback):
    X, y = [], []
    for i in range(lookback, len(data)):
        X.append(data[i - lookback:i])
        y.append(data[i])
    return np.array(X), np.array(y)

# Spliting the data into train and test sets
train_size = int(len(scaled_data) * 0.8)
train_data, test_data = scaled_data[:train_size], scaled_data[train_size:]

# Creating input-output pairs for train and test sets
lookback = 10
X_train, y_train = create_sequences(train_data, lookback)
X_test, y_test = create_sequences(test_data, lookback)

# Reshaping input to be 3D [samples, time steps, features] for LSTM
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], sensor_data.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], sensor_data.shape[1]))

# %%
def build_drcnn_model(input_shape, num_filters=64, kernel_size=3, rnn_units=50, dropout_rate=0.5):
    model = Sequential()
    model.add(Conv1D(num_filters, kernel_size, padding='same', dilation_rate=1, input_shape=input_shape))
    model.add(Activation('relu'))
    model.add(Conv1D(num_filters, kernel_size, padding='same', dilation_rate=2))
    model.add(Activation('relu'))
    model.add(SimpleRNN(rnn_units, return_sequences=False))
    model.add(Dropout(dropout_rate))
    model.add(Dense(input_shape[1]))
    return model

# %%
# Get the input shape from the training data
input_shape = (X_train.shape[1], X_train.shape[2])

# Build the DRCNN model
model = build_drcnn_model(input_shape)

# Compile the model
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mean_squared_error')

# %%
batch_size = 64
epochs = 50
validation_split = 0.2

history = model.fit(
    X_train, y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=validation_split,
    shuffle=False
)
# Out:
# Epoch 1/50
# 343/343 [==============================] - 3s 6ms/step - loss: 0.1195 - val_loss: 0.0403
# Epoch 2/50
# 343/343 [==============================] - 2s 5ms/step - loss: 0.0521 - val_loss: 0.0388
# Epoch 3/50
# 343/343 [==============================] - 2s 5ms/step - loss: 0.0439 - val_loss: 0.0332
# Epoch 4/50
# 343/343 [==============================] - 2s 5ms/step - loss: 0.0397 - val_loss: 0.0322
# Epoch 5/50
# 343/343 [==============================] - 2s 5ms/step - loss: 0.0369 - val_loss: 0.0326
# Epoch 6/50
# 343/343 [==============================] - 2s 5ms/step - loss: 0.0354 - val_loss: 0.0320
# Epoch 7/50
# 343/343 [==============================] - 2s 5ms/step - loss: 0.0340 - val_loss: 0.0313
# Epoch 8/50
# 343/343 [==============================] - 2s 6ms/step - loss: 0.0329 - val_loss: 0.0312
# Epoch 9/50
# 343/343 [==============================] - 2s 5ms/step - loss: 0.0321 - val_loss: 0.0313
# Epoch 10/50
# 343/343 [==============================] - 2s 5ms/step - loss: 0.0314 - val_loss: 0.0310
# Epoch 11/50
# 343/343 [==============================] - 2s 5ms/step - loss: 0.0307 - val_loss: 0.0327
# Epoch 12/50
# 343/343 [==============================] - 2s 5ms/step - loss: 0.0299 - val_loss: 0.0310
# Epoch 13/50
# 343/343 [==============================] - 2s 6ms/step - loss: 0.0294 - val_loss: 0.0307
# Epoch 14/50
# 343/343 [==============================] - 2s 5ms/step - loss: 0.0287 - val_loss: 0.0302
# Epoch 15/50
# 343/343 [==============================] - 2s 5ms/step - loss: 0.0281 - val_loss: 0.0311
# Epoch 16/50
# 343/343 [==============================] - 2s 5ms/step - loss: 0.0276 - val_loss: 0.0306
# Epoch 17/50
# 343/343 [==============================] - 2s 5ms/step - loss: 0.0271 - val_loss: 0.0305
# Epoch 18/50
# 343/343 [==============================] - 2s 6ms/step - loss: 0.0268 - val_loss: 0.0301
# Epoch 19/50
# 343/343 [==============================] - 2s 6ms/step - loss: 0.0266 - val_loss: 0.0297
# Epoch 20/50
# 343/343 [==============================] - 2s 5ms/step - loss: 0.0260 - val_loss: 0.0298
# Epoch 21/50
# 343/343 [==============================] - 2s 6ms/step - loss: 0.0260 - val_loss: 0.0291
# Epoch 22/50
# 343/343 [==============================] - 2s 6ms/step - loss: 0.0257 - val_loss: 0.0291
# Epoch 23/50
# 343/343 [==============================] - 2s 6ms/step - loss: 0.0255 - val_loss: 0.0286
# Epoch 24/50
# 343/343 [==============================] - 2s 6ms/step - loss: 0.0257 - val_loss: 0.0293
# Epoch 25/50
# 343/343 [==============================] - 2s 6ms/step - loss: 0.0257 - val_loss: 0.0289
# Epoch 26/50
# 343/343 [==============================] - 2s 6ms/step - loss: 0.0256 - val_loss: 0.0283
# Epoch 27/50
# 343/343 [==============================] - 2s 6ms/step - loss: 0.0260 - val_loss: 0.0286
# Epoch 28/50
# 343/343 [==============================] - 2s 7ms/step - loss: 0.0254 - val_loss: 0.0290
# Epoch 29/50
# 343/343 [==============================] - 2s 6ms/step - loss: 0.0256 - val_loss: 0.0290
# Epoch 30/50
# 343/343 [==============================] - 2s 6ms/step - loss: 0.0253 - val_loss: 0.0290
# Epoch 31/50
# 343/343 [==============================] - 2s 6ms/step - loss: 0.0256 - val_loss: 0.0284
# Epoch 32/50
# 343/343 [==============================] - 2s 6ms/step - loss: 0.0252 - val_loss: 0.0288
# Epoch 33/50
# 343/343 [==============================] - 2s 6ms/step - loss: 0.0254 - val_loss: 0.0287
# Epoch 34/50
# 343/343 [==============================] - 2s 6ms/step - loss: 0.0255 - val_loss: 0.0290
# Epoch 35/50
# 343/343 [==============================] - 2s 6ms/step - loss: 0.0252 - val_loss: 0.0284
# Epoch 36/50
# 343/343 [==============================] - 2s 6ms/step - loss: 0.0248 - val_loss: 0.0284
# Epoch 37/50
# 343/343 [==============================] - 2s 6ms/step - loss: 0.0250 - val_loss: 0.0281
# Epoch 38/50
# 343/343 [==============================] - 2s 6ms/step - loss: 0.0248 - val_loss: 0.0286
# Epoch 39/50
# 343/343 [==============================] - 2s 6ms/step - loss: 0.0249 - val_loss: 0.0285
# Epoch 40/50
# 343/343 [==============================] - 2s 6ms/step - loss: 0.0247 - val_loss: 0.0280
# Epoch 41/50
# 343/343 [==============================] - 2s 6ms/step - loss: 0.0244 - val_loss: 0.0283
# Epoch 42/50
# 343/343 [==============================] - 2s 6ms/step - loss: 0.0247 - val_loss: 0.0282
# Epoch 43/50
# 343/343 [==============================] - 2s 6ms/step - loss: 0.0247 - val_loss: 0.0278
# Epoch 44/50
# 343/343 [==============================] - 2s 6ms/step - loss: 0.0243 - val_loss: 0.0281
# Epoch 45/50
# 343/343 [==============================] - 2s 6ms/step - loss: 0.0243 - val_loss: 0.0279
# Epoch 46/50
# 343/343 [==============================] - 2s 6ms/step - loss: 0.0242 - val_loss: 0.0277
# Epoch 47/50
# 343/343 [==============================] - 2s 6ms/step - loss: 0.0245 - val_loss: 0.0285
# Epoch 48/50
# 343/343 [==============================] - 2s 6ms/step - loss: 0.0252 - val_loss: 0.0278
# Epoch 49/50
# 343/343 [==============================] - 2s 6ms/step - loss: 0.0241 - val_loss: 0.0275
# Epoch 50/50
# 343/343 [==============================] - 2s 6ms/step - loss: 0.0242 - val_loss: 0.0280

# %%
test_loss = model.evaluate(X_test, y_test)
print(f"Test loss (MSE): {test_loss}")
y_pred = model.predict(X_test)
# Out:
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0293
# Test loss (MSE): 0.029269907623529434
# 214/214 [==============================] - 1s 2ms/step

# %%
import matplotlib.pyplot as plt

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Rescale the predicted and true values back to the original scale
y_pred_rescaled = scaler.inverse_transform(y_pred)
y_test_rescaled = scaler.inverse_transform(y_test)

# Calculate MAE, RMSE, and R-squared
mae = mean_absolute_error(y_test_rescaled, y_pred_rescaled)
rmse = np.sqrt(mean_squared_error(y_test_rescaled, y_pred_rescaled))
r2 = r2_score(y_test_rescaled, y_pred_rescaled)

print(f"Mean Absolute Error (MAE): {mae}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"R-squared: {r2}")
# Out:
# Mean Absolute Error (MAE): 6.449961028245035
# Root Mean Squared Error (RMSE): 11.965555147289093
# R-squared: 0.7194887797779116

# %%
import matplotlib.pyplot as plt

# Choose a specific sensor ID (e.g., '773869')
sensor_id = '767541'

# Find the index of the sensor ID in the dataset
sensor_index = list(data.columns).index(sensor_id) - 1  # Subtract 1 to account for the timestamp column

# Plot true vs. predicted values for the specific sensor
plt.plot(y_test_rescaled[:, sensor_index], label='True Values')
plt.plot(y_pred_rescaled[:, sensor_index], label='Predicted Values')
plt.title(f'Sensor {sensor_id} - True vs. Predicted Values')
plt.xlabel('Time')
plt.ylabel('Speed')
plt.legend()
plt.show()

# %%
n = 100  # Number of future time steps to predict
input_sequence = X_test[-1]  # Use the last sequence in the test data as the input

future_predictions = []

for i in range(n):
    prediction = model.predict(input_sequence[np.newaxis, :, :])
    future_predictions.append(prediction[0])

    # Update the input_sequence with the new prediction
    input_sequence[:-1] = input_sequence[1:]
    input_sequence[-1] = prediction

# Rescale the future predictions back to the original scale
future_predictions_rescaled = scaler.inverse_transform(future_predictions)
# Out:
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step

# %%
# Choose a specific sensor ID (e.g., '773869')
sensor_id = '767541'

# Find the index of the sensor ID in the dataset
sensor_index = list(data.columns).index(sensor_id) - 1  # Subtract 1 to account for the timestamp column

# Rescale the test data and predictions to the original scale
y_test_rescaled = scaler.inverse_transform(y_test)
y_pred_rescaled = scaler.inverse_transform(y_pred)

# Plot the true values and predicted values for the sensor
plt.plot(y_test_rescaled[:, sensor_index], label='True Values')
plt.plot(y_pred_rescaled[:, sensor_index], label='Predicted Values')

# If you want to visualize the future predictions
if 'future_predictions_rescaled' in locals():
    prediction_start = len(y_test_rescaled)
    prediction_end = prediction_start + len(future_predictions_rescaled)
    prediction_range = range(prediction_start, prediction_end)
    plt.plot(prediction_range, future_predictions_rescaled[:, sensor_index], label='Future Predictions')

plt.xlabel('Time Steps')
plt.ylabel('Sensor Value')
plt.title(f'Sensor {sensor_id} - True vs. Predicted Values')
plt.legend()
plt.show()

# %%
# Read dataset
df = pd.read_csv("METR-LA.csv")

# Convert timestamp to datetime object
df['timestamp'] = pd.to_datetime(df['timestamp'])

# Set timestamp as index
df = df.set_index('timestamp')
train_ratio = 0.8
train_size = int(len(df) * train_ratio)
test_df = df[train_size:]

# %%
no_threshold=0
low_threshold = 30
medium_threshold = 50
given_time_index = 50  # Replace this with the desired index from the test dataset
traffic_speeds = test_df.iloc[given_time_index].values

# %%
def classify_traffic(sensor_ids, speeds, low_threshold, medium_threshold, no_threshold):
    traffic_levels = {}

    for sensor_id, speed in zip(sensor_ids, speeds):
        if speed == no_threshold:
            traffic_levels[sensor_id] = "no Traffic"
        elif speed >= medium_threshold:
            traffic_levels[sensor_id] = "Low"
        elif speed <= medium_threshold and speed >= low_threshold:
            traffic_levels[sensor_id] = "Medium"
        else:
            traffic_levels[sensor_id] = "High"

    return traffic_levels

# %%
traffic_levels = classify_traffic(test_df.columns, traffic_speeds, low_threshold, medium_threshold, no_threshold)

print("Low Traffic Sensors:")
print([sensor_id for sensor_id, level in traffic_levels.items() if level == "Low"])

print("\nNo Traffic Sensors:")
print([sensor_id for sensor_id, level in traffic_levels.items() if level == "no Traffic"])

print("\nMedium Traffic Sensors:")
print([sensor_id for sensor_id, level in traffic_levels.items() if level == "Medium"])

print("\nHigh Traffic Sensors:")
print([sensor_id for sensor_id, level in traffic_levels.items() if level == "High"])
# Out:
# Low Traffic Sensors:
# ['773869', '767541', '767542', '717447', '717445', '773062', '767620', '737529', '767471', '773906', '769953', '769402', '769819', '717578', '717804', '767572', '767573', '773013', '764424', '717819', '769941', '760987', '718204', '769418', '773927', '774012', '774011', '767609', '769831', '773953', '767470', '764949', '767366', '773939', '774067', '769443', '767750', '767751', '767610', '773880', '717497', '717491', '717492', '765176', '717498', '718066', '765164', '769431', '717610', '767621', '772596', '767351', '716571', '767585', '773024', '717483', '717480', '764120', '717818', '718076', '718072', '767455', '767454', '761599', '773916', '716968', '769467', '717573', '717572', '717571', '717570', '764760', '769847', '767523', '769867', '717473', '759591', '764781', '765099', '762329', '767509', '769358', '772513', '718496', '773904', '718499', '761003', '717502', '759602', '763995', '773996', '773995', '717469', '764106', '717465', '764794', '717460', '717463', '769345', '772669', '717582', '717583', '717580', '716949', '717587', '772178', '717585', '768469', '767554', '773975', '773974', '717510', '717513', '717825', '767495', '767494', '717821', '717823', '717459', '769926', '764858', '717452', '759772', '717456', '769372', '774204', '769806', '717592', '717595', '718141']
#
# No Traffic Sensors:
# ['717481', '716939']
#
# Medium Traffic Sensors:
# ['717446', '765604', '716331', '771667', '716337', '769403', '716960', '769388', '716328', '768066', '772140', '716956', '761604', '716554', '773954', '718064', '772597', '773023', '718379', '718371', '717099', '717576', '718089', '716942', '718090', '716953', '716951', '765182', '769346', '764853', '716943', '717450', '717453', '771673', '772167', '772168']
#
# High Traffic Sensors:
# ['717816', '716339', '765273', '769405', '716941', '773012', '718045', '760024', '769359', '760650', '717495', '716955', '769444', '764766', '717490', '717493', '717499', '765171', '769430', '767053', '767350', '717486', '772151', '717489', '717488', '717608', '717472', '716958', '717504', '717508', '765265', '717468', '717466', '717461', '717462', '764101', '717458', '717590', '769373']

# %%
future_time_index = 5  # Replace this with the desired index from the future_predictions
future_traffic_speeds = future_predictions_rescaled [future_time_index]
future_traffic_speeds = np.append(future_traffic_speeds,55.6697059)

# %%
future_traffic_levels = classify_traffic(test_df.columns, future_traffic_speeds, low_threshold, medium_threshold, no_threshold)
future_traffic_levels['769373']='Low'
print("Low Traffic Sensors:")
print([sensor_id for sensor_id, level in future_traffic_levels.items() if level == "Low"])

print("\nNo Traffic Sensors:")
print([sensor_id for sensor_id, level in future_traffic_levels.items() if level == "no Traffic"])

print("\nMedium Traffic Sensors:")
print([sensor_id for sensor_id, level in future_traffic_levels.items() if level == "Medium"])

print("\nHigh Traffic Sensors:")
print([sensor_id for sensor_id, level in future_traffic_levels.items() if level == "High"])
# Out:
# Low Traffic Sensors:
# ['773869', '767541', '717446', '773062', '767620', '737529', '717816', '765604', '773906', '716337', '769402', '769403', '717804', '767572', '773012', '773013', '764424', '769388', '717819', '769418', '760024', '774012', '774011', '760650', '716956', '717495', '773953', '764949', '773954', '773939', '769443', '767750', '767751', '767610', '773880', '717497', '717490', '717499', '765171', '718064', '718066', '769430', '717610', '767053', '772596', '772597', '767351', '773023', '717480', '717486', '718371', '717489', '717818', '718076', '718072', '767455', '767454', '761599', '769467', '717571', '718089', '769847', '717608', '718090', '717473', '765099', '716951', '767509', '773904', '717502', '717508', '765265', '773996', '717468', '772669', '717583', '716949', '772178', '768469', '764101', '767554', '773975', '717825', '767495', '767494', '717459', '774204', '769806', '717590', '717592', '717595', '772168', '769373']
#
# No Traffic Sensors:
# []
#
# Medium Traffic Sensors:
# ['767542', '717447', '717445', '716339', '765273', '771667', '769953', '769405', '716941', '717578', '716960', '767573', '716328', '769941', '760987', '768066', '773927', '767609', '769831', '761604', '716554', '716955', '767366', '774067', '764766', '717491', '717492', '717493', '765176', '717498', '765164', '769431', '767621', '767350', '716571', '767585', '773024', '717483', '718379', '717481', '764120', '772151', '717488', '773916', '716968', '717576', '717573', '717572', '717570', '764760', '716942', '769867', '717472', '759591', '764781', '765182', '769358', '772513', '716958', '718496', '718499', '764853', '759602', '763995', '773995', '717469', '764106', '717465', '764794', '717466', '717461', '717460', '717463', '717462', '769345', '716943', '717582', '717580', '717587', '716939', '773974', '717510', '717513', '717821', '717823', '717458', '769926', '764858', '717450', '717452', '717453', '759772', '772167', '769372', '718141']
#
# High Traffic Sensors:
# ['767471', '716331', '769819', '718204', '718045', '772140', '769359', '767470', '769444', '717099', '767523', '762329', '716953', '769346', '761003', '717504', '717585', '717456', '771673']

# %%
def plot_sensor_positions_on_map(sensor_positions, traffic_levels):
    # Create a map centered at the average latitude and longitude of the sensors
    avg_lat = sensor_positions["latitude"].mean()
    avg_lon = sensor_positions["longitude"].mean()
    m = folium.Map(location=[avg_lat, avg_lon], zoom_start=10)

    # Define colors for different traffic levels
    colors = {
        "no Traffic": "gray",
        "Low": "green",
        "Medium": "orange",
        "High": "red",
    }

    # Add markers for each sensor
    for idx, row in sensor_positions.iterrows():
        sensor_id = row["sensor_id"]
        lat = row["latitude"]
        lon = row["longitude"]
        level = traffic_levels[sensor_id]
        color = colors[level]

        folium.Marker(
            location=[lat, lon],
            icon=folium.Icon(color=color),
            tooltip=f"Sensor ID: {sensor_id}, Traffic: {level}",
        ).add_to(m)

    return m

# %%
# Read sensor positions from the file
sensor_positions = pd.read_csv("graph_sensor_locations.csv")

# Map sensor IDs to their index in the dataset
sensor_id_to_index = {sensor_id: idx for idx, sensor_id in enumerate(sensor_positions["sensor_id"])}



# Classify traffic levels for the given time index
traffic_levels_given_time = classify_traffic(
    sensor_positions["sensor_id"],
    traffic_speeds,
    low_threshold,
    medium_threshold,
    no_threshold,
)

# Plot the sensor positions with their traffic classification on a map
m = plot_sensor_positions_on_map(sensor_positions, traffic_levels_given_time)
m.save("sensor_positions_map_DRCNN.html")  # Save the map as an HTML file
m  # Display the map in the notebook
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5513c1c072c06ba0f9f75ede6b3e4e89 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5513c1c072c06ba0f9f75ede6b3e4e89&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5513c1c072c06ba0f9f75ede6b3e4e89 = L.map(
#                 &quot;map_5513c1c072c06ba0f9f75ede6b3e4e89&quot;,
#                 {
#                     center: [34.13685429951691, -118.32048154589373],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_31033563d98875e9babe22079ceac5ff = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5513c1c072c06ba0f9f75ede6b3e4e89);
#
#
#             var marker_5385d9a22d2c8405d7e54ba952281ff0 = L.marker(
#                 [34.15497, -118.31829],
#                 {}
#             ).addTo(map_5513c1c072c06ba0f9f75ede6b3e4e89);
#
#
#             var icon_09606eb621bc286fdf0c956087d7f84b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5385d9a22d2c8405d7e54ba952281ff0.setIcon(icon_09606eb621bc286fdf0c956087d7f84b);
#
#
#             marker_5385d9a22d2c8405d7e54ba952281ff0.bindTooltip(
#                 `&lt;div&gt;
#                      Sensor ID: 773869.0, Traffic: Low
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_84fd0d23490276fe3f73e172fcbcad24 = L.marker(
#                 [34.11621, -118.23799],
#                 {}
#             ).addTo(map_5513c1c072c06ba0f9f75ede6b3e4e89);
#
#
#             var icon_022060e2da4499ad695b90ff26753086 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_84fd0d23490276fe3f73e172fcbcad24.setIcon(icon_022060e2da4499ad695b90ff26753086);
#
#
#             marker_84fd0d23490276fe3f73e172fcbcad24.bindTooltip(
#                 `&lt;div&gt;
#                      Sensor ID: 767541.0, Traffic: Low
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a0d54309bd4143423763b2e4ef1c045f = L.marker(
#                 [34.11641, -118.23819],
#                 {}
#             ).addTo(map_5513c1c072c06ba0f9f75ede6b3e4e89);
#
#
#             var icon_7d4e9708b9ac7816c47c49083cdd51d0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a0d54309bd4143423763b2e4ef1c045f.setIcon(icon_7d4e9708b9ac7816c47c49083cdd51d0);
#
#
#             marker_a0d54309bd4143423763b2e4ef1c045f.bindTooltip(
#                 `&lt;div&gt;
#                      Sensor ID: 767542.0, Traffic: Low
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_904311ed82c36636cfcacc07e2675d46 = L.marker(
#                 [34.07248, -118.26772],
#                 {}
#             ).addTo(map_5513c1c072c06ba0f9f75ede6b3e4e89);
#
#
#             var icon_1726ee4d5a73537aea51cf1e8e139b9d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_904311ed82c36636cfcacc07e2675d46.setIcon(icon_1726ee4d5a73537aea51cf1e8e139b9d);
#
#
#             marker_904311ed82c36636cfcacc07e2675d46.bindTooltip(
#                 `&lt;div&gt;
#                      Sensor ID: 717447.0, Traffic: Low
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_82bf35867abcb82518c18a9de258294b = L.marker(
#                 [34.07142, -118.26572],
#                 {}
#             ).addTo(map_5513c1c072c06ba0f9f75ede6b3e4e89);
#
#
#             var icon_129371731f755863ca2c8e9eb2758e57 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&qu

# %%
# Read sensor positions from the file
sensor_positions = pd.read_csv("graph_sensor_locations.csv")

# Map sensor IDs to their index in the dataset
sensor_id_to_index = {sensor_id: idx for idx, sensor_id in enumerate(sensor_positions["sensor_id"])}



# Classify traffic levels for the given time index
traffic_levels_given_time = classify_traffic(
    sensor_positions["sensor_id"],
    future_traffic_speeds,
    low_threshold,
    medium_threshold,
    no_threshold,
)

# Plot the sensor positions with their traffic classification on a map
m = plot_sensor_positions_on_map(sensor_positions, traffic_levels_given_time)
m.save("sensor_positions_map.html")  # Save the map as an HTML file
m  # Display the map in the notebook
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_151e4d8c4786e34ef91172e0092be862 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_151e4d8c4786e34ef91172e0092be862&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_151e4d8c4786e34ef91172e0092be862 = L.map(
#                 &quot;map_151e4d8c4786e34ef91172e0092be862&quot;,
#                 {
#                     center: [34.13685429951691, -118.32048154589373],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a248ab8d29dfe05ca0d96d31e57f49c7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_151e4d8c4786e34ef91172e0092be862);
#
#
#             var marker_e8ba386fc05740dcd9ae929f60c0467e = L.marker(
#                 [34.15497, -118.31829],
#                 {}
#             ).addTo(map_151e4d8c4786e34ef91172e0092be862);
#
#
#             var icon_894ca353ed3f669b959fbf7dbd7ee84c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e8ba386fc05740dcd9ae929f60c0467e.setIcon(icon_894ca353ed3f669b959fbf7dbd7ee84c);
#
#
#             marker_e8ba386fc05740dcd9ae929f60c0467e.bindTooltip(
#                 `&lt;div&gt;
#                      Sensor ID: 773869.0, Traffic: Low
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_70cf40bd6c63283c6374d29552e15fc7 = L.marker(
#                 [34.11621, -118.23799],
#                 {}
#             ).addTo(map_151e4d8c4786e34ef91172e0092be862);
#
#
#             var icon_4d86dafa9464ac5b1ad681077c8339d8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_70cf40bd6c63283c6374d29552e15fc7.setIcon(icon_4d86dafa9464ac5b1ad681077c8339d8);
#
#
#             marker_70cf40bd6c63283c6374d29552e15fc7.bindTooltip(
#                 `&lt;div&gt;
#                      Sensor ID: 767541.0, Traffic: Low
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_52e8bd308cd2b2ba8558040df4e2ddcd = L.marker(
#                 [34.11641, -118.23819],
#                 {}
#             ).addTo(map_151e4d8c4786e34ef91172e0092be862);
#
#
#             var icon_b6379fdc737e7d4222d4cf58938570ed = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_52e8bd308cd2b2ba8558040df4e2ddcd.setIcon(icon_b6379fdc737e7d4222d4cf58938570ed);
#
#
#             marker_52e8bd308cd2b2ba8558040df4e2ddcd.bindTooltip(
#                 `&lt;div&gt;
#                      Sensor ID: 767542.0, Traffic: Medium
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a0fd4a78ba0dfdb40393e151216b5f43 = L.marker(
#                 [34.07248, -118.26772],
#                 {}
#             ).addTo(map_151e4d8c4786e34ef91172e0092be862);
#
#
#             var icon_fc01db91a29df174c420757a04b62442 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a0fd4a78ba0dfdb40393e151216b5f43.setIcon(icon_fc01db91a29df174c420757a04b62442);
#
#
#             marker_a0fd4a78ba0dfdb40393e151216b5f43.bindTooltip(
#                 `&lt;div&gt;
#                      Sensor ID: 717447.0, Traffic: Medium
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_53a2e5e05c6b20f3cfe32ef852f94f67 = L.marker(
#                 [34.07142, -118.26572],
#                 {}
#             ).addTo(map_151e4d8c4786e34ef91172e0092be862);
#
#
#             var icon_25a6c8e8f794fec949fa0349c477405b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;g
